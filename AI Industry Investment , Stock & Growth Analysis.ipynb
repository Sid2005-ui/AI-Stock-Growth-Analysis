# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Siddhant\Downloads\Python Project\ai_stock&growth_analysys.csv')

# %%
df.shape
# Out:
# (10959, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  object
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 599.4+ KB

# %%
df
# Out:
#              Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0      2015-01-01  OpenAI                 5.92               0.63
# 1      2015-01-02  OpenAI                 5.41               1.81
# 2      2015-01-03  OpenAI                 4.50               0.61
# 3      2015-01-04  OpenAI                 5.45               0.95
# 4      2015-01-05  OpenAI                 3.40               1.48
# ...           ...     ...                  ...                ...
# 10954  2024-12-27    Meta               100.19             103.54
# 10955  2024-12-28    Meta                99.12             102.37
# 10956  2024-12-29    Meta                98.95             103.11
# 10957  2024-12-30    Meta               100.74             103.21
# 10958  2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 0                   -36.82   NaN           -0.36
# 1                    80.59   NaN            0.41
# ...

# %%
df.head(10)
# Out:
#          Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0  2015-01-01  OpenAI                 5.92               0.63
# 1  2015-01-02  OpenAI                 5.41               1.81
# 2  2015-01-03  OpenAI                 4.50               0.61
# 3  2015-01-04  OpenAI                 5.45               0.95
# 4  2015-01-05  OpenAI                 3.40               1.48
# 5  2015-01-06  OpenAI                 5.47               1.08
# 6  2015-01-07  OpenAI                 6.95               0.67
# 7  2015-01-08  OpenAI                 5.06               1.43
# 8  2015-01-09  OpenAI                 5.26               0.33
# 9  2015-01-10  OpenAI                 2.00               0.74
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%
# 0               -36.82   NaN           -0.36
# 1                80.59   NaN            0.41
# 2               -38.88   NaN            0.23
# 3                -5.34   NaN            0.93
# 4                48.45   NaN           -0.09
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  datetime64[ns]
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 599.4+ KB

# %%
df.head(5)
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%
# 0               -36.82   NaN           -0.36
# 1                80.59   NaN            0.41
# 2               -38.88   NaN            0.23
# 3                -5.34   NaN            0.93
# 4                48.45   NaN           -0.09

# %%
df.tail(5)
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 10954               417.68   NaN           -0.66
# 10955               411.86   NaN           -0.57
# 10956               415.54   NaN           -0.52
# 10957               416.03   NaN            0.22
# 10958               417.04   NaN           -0.16

# %%
df['Company'].unique()
# Out:
# array(['OpenAI', 'Google', 'Meta'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Date                       0
# Company                    0
# R&D_Spending_USD_Mn        0
# AI_Revenue_USD_Mn          0
# AI_Revenue_Growth_%        0
# Event                  10726
# Stock_Impact_%             0
# dtype: int64

# %%
df['Year'] = df['Date'].dt.year

# %%
percentage_mv = df.isnull().sum() / len(df) * 100
plt.title("Percentage of Missing Value")
plt.xticks(rotation=45)
plt.ylabel("Percentage")
plt.plot(percentage_mv.index,percentage_mv,marker='o')

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
print("Company's investment in research of AI")
inv = df.groupby('Company')['R&D_Spending_USD_Mn'].sum()/1000
print(inv)
# Out:
# Company's investment in research of AI
# Company
# Google    423.34114
# Meta      264.53307
# OpenAI     26.48277
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
plt.bar(inv.index , inv.values , color= ['black' , 'LightBlue' , 'Blue'] )
plt.ylabel('Investment in Billions')
plt.title('Investment in Research by Companies')
plt.show()

# %%
print("Companies Revenue")
rv = df.groupby('Company')['AI_Revenue_USD_Mn'].sum()/1000
print(rv)
# Out:
# Companies Revenue
# Company
# Google    284.49838
# Meta      189.62182
# OpenAI      9.46289
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
plt.bar(rv.index , rv.values , color= ['darkred' , 'red' , 'red']   )
plt.ylabel('Revenue in Billions')
plt.title('Revenue Earned by Companies')
plt.show()

# %%
plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.bar(inv.index , inv.values , color= ['black' , 'LightBlue' , 'Blue'] )
plt.ylabel('Investment in Billions')
plt.title('Investment in Research by Companies')

plt.subplot(1,2,2)
plt.bar(rv.index , rv.values , color= ['darkred' , 'red' , 'red'] )
plt.ylabel('Revenue in Billions')
plt.title('Revenue Earned by Companies')
# Out:
# Text(0.5, 1.0, 'Revenue Earned by Companies')

# %%
df['Net Profit'] = df['AI_Revenue_USD_Mn'] - df['R&D_Spending_USD_Mn']

# %%
df
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0     2015-01-01  OpenAI                 5.92               0.63
# 1     2015-01-02  OpenAI                 5.41               1.81
# 2     2015-01-03  OpenAI                 4.50               0.61
# 3     2015-01-04  OpenAI                 5.45               0.95
# 4     2015-01-05  OpenAI                 3.40               1.48
# ...          ...     ...                  ...                ...
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%  Year  Net Profit
# 0                   -36.82   NaN           -0.36  2015       -5.29
# ...

# %%
retrn = (rv-inv)/inv  #rate of return 
retrn
# Out:
# Company
# Google   -0.327969
# Meta     -0.283183
# OpenAI   -0.642677
# dtype: float64

# %%
pr = df.groupby('Company')['Net Profit'].sum()/1000
print(pr)
# Out:
# Company
# Google   -138.84276
# Meta      -74.91125
# OpenAI    -17.01988
# Name: Net Profit, dtype: float64

# %%
plt.plot(pr.index , pr.values)
plt.ylabel('Profit')
plt.show()

# %%
df.drop(columns=['Net Profit'], inplace=True)

# %%
openai_data = df[df['Company']=='OpenAI']
google_data = df[df['Company']=='Google']
meta_data = df[df['Company']=='Meta']

# %%
(openai_data)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0    2015-01-01  OpenAI                 5.92               0.63
# 1    2015-01-02  OpenAI                 5.41               1.81
# 2    2015-01-03  OpenAI                 4.50               0.61
# 3    2015-01-04  OpenAI                 5.45               0.95
# 4    2015-01-05  OpenAI                 3.40               1.48
# ...         ...     ...                  ...                ...
# 3648 2024-12-27  OpenAI                10.06               4.71
# 3649 2024-12-28  OpenAI                 9.67               5.32
# 3650 2024-12-29  OpenAI                 9.17               5.46
# 3651 2024-12-30  OpenAI                10.36               6.31
# 3652 2024-12-31  OpenAI                10.24               4.92
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0                  -36.82   NaN           -0.36  2015
# 1                   80.59   NaN            0.41  2015
# ...

# %%
google_data
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3653 2015-01-01  Google                79.89              30.19
# 3654 2015-01-02  Google                78.99              30.44
# 3655 2015-01-03  Google                79.20              30.46
# 3656 2015-01-04  Google                79.59              30.55
# 3657 2015-01-05  Google                81.50              30.59
# ...         ...     ...                  ...                ...
# 7301 2024-12-27  Google               162.16             155.36
# 7302 2024-12-28  Google               159.69             154.47
# 7303 2024-12-29  Google               161.69             154.59
# 7304 2024-12-30  Google               158.48             155.05
# 7305 2024-12-31  Google               159.48             154.77
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 3653                 0.64   NaN           -0.02  2015
# 3654                 1.47   NaN           -0.98  2015
# ...

# %%
meta_data
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 7306  2015-01-01    Meta                50.39              18.95
# 7307  2015-01-02    Meta                49.80              19.77
# 7308  2015-01-03    Meta                49.09              19.96
# 7309  2015-01-04    Meta                50.66              20.48
# 7310  2015-01-05    Meta                51.36              19.84
# ...          ...     ...                  ...                ...
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 7306                 -5.23   NaN           -0.42  2015
# 7307                 -1.16   NaN            0.63  2015
# ...

# %%
plt.plot(openai_data['Date'] , openai_data['Stock_Impact_%'] , color='Black')
plt.ylabel("Stock Impact_%")
plt.xlabel("Years")
plt.title("Stock Impact % of Open AI")
# Out:
# Text(0.5, 1.0, 'Stock Impact % of Open AI')

# %%
plt.plot(openai_data['Date'] , openai_data['AI_Revenue_Growth_%'] , color='Black')
plt.ylabel("AI_Revenue_Growth_%")
plt.xlabel("Years")
plt.title("Growth % of Open AI over Years")
# Out:
# Text(0.5, 1.0, 'Growth % of Open AI over Years')

# %%
openai_data.sort_values(by = 'Stock_Impact_%' , ascending = False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3408 2024-05-01  OpenAI                10.91               5.34
# 2994 2023-03-14  OpenAI                 7.78               4.05
# 2890 2022-11-30  OpenAI                10.60               3.18
# 2652 2022-04-06  OpenAI                 9.24               3.48
# 1988 2020-06-11  OpenAI                 5.90               2.62
# ...         ...     ...                  ...                ...
# 3590 2024-10-30  OpenAI                11.05               5.27
# 1212 2018-04-27  OpenAI                 5.38               1.76
# 1303 2018-07-27  OpenAI                 7.44               0.97
# 2480 2021-10-16  OpenAI                 8.39               2.78
# 3350 2024-03-04  OpenAI                10.82               4.77
#
#       AI_Revenue_Growth_%                        Event  Stock_Impact_%  Year
# 3408               434.27    GPT-5 release (predicted)           18.50  2024
# ...

# %%
plt.plot(meta_data['Date'] , meta_data['Stock_Impact_%'] , color='b')
plt.ylabel("Stock Impact_%")
plt.xlabel("Years")
plt.title("Stock Impact % of Meta")
# Out:
# Text(0.5, 1.0, 'Stock Impact % of Meta')

# %%
plt.plot(meta_data['Date'] , meta_data['AI_Revenue_Growth_%'] , color='b')
plt.ylabel("AI_Revenue_Growth_%")
plt.xlabel("Years")
plt.title("Growth % of Meta over Years")
# Out:
# Text(0.5, 1.0, 'Growth % of Meta over Years')

# %%
meta_data.sort_values(by = 'Stock_Impact_%' , ascending = False)
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 10731 2024-05-18    Meta               103.64             103.05
# 10426 2023-07-18    Meta                92.44              85.67
# 10282 2023-02-24    Meta                93.71              86.98
# 9156  2020-01-25    Meta                72.73              49.10
# 7526  2015-08-09    Meta                48.97              19.95
# ...          ...     ...                  ...                ...
# 10604 2024-01-12    Meta                99.37             104.28
# 7875  2016-07-23    Meta                53.76              23.97
# 8026  2016-12-21    Meta                53.18              23.42
# 9964  2022-04-12    Meta                84.90              71.99
# 10785 2024-07-11    Meta               100.78             102.92
#
#        AI_Revenue_Growth_%                            Event  Stock_Impact_%  \
# 10731               415.23      LLaMA 3 release (predicted)            7.40
# ...

# %%
plt.plot(google_data['Date'] , google_data['Stock_Impact_%'] , color='tomato')
plt.ylabel("Stock Impact_%")
plt.xlabel("Years")
plt.title("Stock Impact % of Google")
# Out:
# Text(0.5, 1.0, 'Stock Impact % of Google')

# %%
plt.plot(google_data['Date'] , meta_data['AI_Revenue_Growth_%'] , color='tomato')
plt.ylabel("AI_Revenue_Growth_%")
plt.xlabel("Years")
plt.title("Growth % of Gemini over Years")
# Out:
# Text(0.5, 1.0, 'Growth % of Gemini over Years')

# %%
google_data.sort_values(by = 'Stock_Impact_%' , ascending = False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 4092 2016-03-15  Google                84.56              36.22
# 6914 2023-12-06  Google               146.59             129.17
# 6654 2023-03-21  Google               149.34             129.76
# 3883 2015-08-19  Google                79.27              30.89
# 6388 2022-06-28  Google               137.71             107.96
# ...         ...     ...                  ...                ...
# 4122 2016-04-14  Google                87.19              36.08
# 4412 2017-01-29  Google                92.21              43.25
# 6303 2022-04-04  Google               138.00             106.81
# 3803 2015-05-31  Google                81.14              29.30
# 5479 2020-01-01  Google               117.24              74.82
#
#       AI_Revenue_Growth_%                            Event  Stock_Impact_%  \
# 4092                20.73          AlphaGo beats Lee Sedol            6.20
# ...

# %%
plt.title("Percentage change in the company's stock price")
plt.ylabel("Percentage")
plt.plot(df[df['Company']=="Google"]['Date'],
            df[df['Company']=="Google"]["Stock_Impact_%"], color='tomato', label="Google")
plt.plot(df[df['Company']=="Meta"]['Date'],
            df[df['Company']=="Meta"]["Stock_Impact_%"], color='b', label="Meta")
plt.plot(df[df['Company']=="OpenAI"]['Date'],
            df[df['Company']=="OpenAI"]["Stock_Impact_%"], color='black', label="OpenAI")
plt.legend()
plt.show()

# %%
sns.scatterplot( x = 'Date' , y = 'AI_Revenue_Growth_%' , data = df, hue = 'Company')
# Out:
# <Axes: xlabel='Date', ylabel='AI_Revenue_Growth_%'>

# %%
df.sort_values(by = ['AI_Revenue_Growth_%']  , ascending = False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3423 2024-05-16  OpenAI                 8.47               6.65
# 3612 2024-11-21  OpenAI                10.16               6.59
# 3627 2024-12-06  OpenAI                 8.51               6.49
# 3645 2024-12-24  OpenAI                 8.79               6.46
# 3508 2024-08-09  OpenAI                 9.92               6.33
# ...         ...     ...                  ...                ...
# 98   2015-04-09  OpenAI                 4.80              -0.25
# 548  2016-07-02  OpenAI                 5.19              -0.29
# 649  2016-10-11  OpenAI                 5.37              -0.35
# 205  2015-07-25  OpenAI                 5.23              -0.42
# 189  2015-07-09  OpenAI                 5.66              -0.55
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 3423               565.50   NaN            0.51  2024
# 3612               558.70   NaN            0.63  2024
# ...

# %%
df.corr(numeric_only = True)
# Out:
#                      R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# R&D_Spending_USD_Mn             1.000000           0.935030
# AI_Revenue_USD_Mn               0.935030           1.000000
# AI_Revenue_Growth_%             0.291245           0.530128
# Stock_Impact_%                 -0.004628          -0.000017
# Year                            0.297701           0.526478
#
#                      AI_Revenue_Growth_%  Stock_Impact_%      Year
# R&D_Spending_USD_Mn             0.291245       -0.004628  0.297701
# AI_Revenue_USD_Mn               0.530128       -0.000017  0.526478
# AI_Revenue_Growth_%             1.000000        0.020937  0.952199
# Stock_Impact_%                  0.020937        1.000000  0.016525
# Year                            0.952199        0.016525  1.000000

# %%
sns.set_style('darkgrid')
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='magma')
plt.title('the heatmap data info')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
 #Average impact on the Stocks of the companies
df.groupby('Company')['Stock_Impact_%'].mean()*100
# Out:
# Company
# Google    2.620860
# Meta      0.976184
# OpenAI    4.070901
# Name: Stock_Impact_%, dtype: float64

# %%
# Average Expenditure on R & D by the companies

df.groupby('Company')['R&D_Spending_USD_Mn'].mean()
# Out:
# Company
# Google    115.888623
# Meta       72.415294
# OpenAI      7.249595
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
# Maximum impact % on a company's stocks
df.groupby('Company')['Stock_Impact_%'].max()
# Out:
# Company
# Google     6.2
# Meta       7.4
# OpenAI    18.5
# Name: Stock_Impact_%, dtype: float64

# %%
stocks = df.groupby(['Year', 'Company'])['Stock_Impact_%'].max()
stocks
# Out:
# Year  Company
# 2015  Google      4.96
#       Meta        4.80
#       OpenAI      3.92
# 2016  Google      6.20
#       Meta        2.14
#       OpenAI      4.66
# 2017  Google      4.42
#       Meta        4.21
#       OpenAI      4.63
# 2018  Google      1.97
#       Meta        4.54
#       OpenAI      4.94
# 2019  Google      3.20
#       Meta        1.86
#       OpenAI      4.20
# 2020  Google      4.18
#       Meta        4.86
#       OpenAI      8.50
# 2021  Google      4.10
#       Meta        4.80
#       OpenAI      7.20
# 2022  Google      4.88
#       Meta        3.98
#       OpenAI     12.00
# 2023  Google      5.80
#       Meta        6.80
#       OpenAI     15.20
# 2024  Google      2.89
#       Meta        7.40
#       OpenAI     18.50
# Name: Stock_Impact_%, dtype: float64

# %%
spending = df.groupby('Company')['R&D_Spending_USD_Mn'].sum()


plt.figure(figsize=(8, 6))
plt.pie(spending, labels=spending.index, autopct='%1.1f%%', startangle=140)
plt.title('R&D Spending Distribution company')
plt.axis('equal')  # Ensures pie is a circle
plt.tight_layout()
plt.show()

# %%
spend = df.groupby('Year')['R&D_Spending_USD_Mn'].sum()/1000

spend
# Out:
# Year
# 2015    49.30423
# 2016    53.34994
# 2017    57.47512
# 2018    62.00216
# 2019    67.07151
# 2020    72.60253
# 2021    78.20732
# 2022    84.39017
# 2023    91.19392
# 2024    98.76008
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
revenue = df.groupby('Year')['AI_Revenue_USD_Mn'].sum()/1000

revenue
# Out:
# Year
# 2015    18.62321
# 2016    22.36120
# 2017    26.77680
# 2018    32.16444
# 2019    38.58032
# 2020    46.45619
# 2021    55.59114
# 2022    66.67424
# 2023    80.04164
# 2024    96.31391
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Scatter for Revenue
plt.scatter(revenue.index, revenue.values, color='blue', label='Revenue', marker='o')

# Scatter for Spending
plt.scatter(spend.index, spend.values, color='green', label='Spent', marker='x')

# Titles and labels
plt.title("Combined R&D Spending of overall Ai industry")
plt.xlabel("Year")
plt.ylabel("Amount in USD $Bill ")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)

# %%
event = pd.pivot_table(
    df,
    index = df['Date'].dt.year,  
    columns = 'Company',         
    values = 'Event',            
    aggfunc = pd.Series.nunique,             
    fill_value = 0                 
)
event.loc['Total'] = event.sum()
print(event)
# Out:
# Company  Google  Meta  OpenAI
# Date
# 2015          5     5       5
# 2016          6     6       5
# 2017          7     3       5
# 2018          5     5       7
# 2019          6     2       4
# 2020          7     7       2
# 2021          7     5       6
# 2022          3     5       6
# 2023          5     4       8
# 2024          3     7       7
# Total        54    49      55

# %%
df.Event.value_counts()
# Out:
# Event
# AI speech recognition release      37
# AI Ads Optimization upgrade        32
# AI partnership deal                32
# AI-powered search update           32
# AI Video Recommendation upgrade    29
# AI ethics policy update            27
# Cloud AI launch                    27
# GPT-1 release                       1
# GPT-2 release                       1
# GPT-3 release                       1
# Codex release                       1
# DALL·E 2 release                    1
# ChatGPT (GPT-3.5) launch            1
# GPT-4 release                       1
# GPT-5 release (predicted)           1
# TensorFlow open-source release      1
# AlphaGo beats Lee Sedol             1
# BERT for Search launch              1
# MUM Search Model launch             1
# Bard chatbot launch                 1
# Gemini AI release                   1
# LLaMA 1 release                     1
# LLaMA 2 release                     1
# LLaMA 3 release (predicted)         1
# Name: count, dtype: int64

# %%
df[ df.Event == 'GPT-4 release']
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2994 2023-03-14  OpenAI                 7.78               4.05
#
#       AI_Revenue_Growth_%          Event  Stock_Impact_%  Year
# 2994               304.57  GPT-4 release            15.2  2023

# %%
gpt4 = df.loc[ 2984 : 3004]

gpt4
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2984 2023-03-04  OpenAI                10.59               4.26
# 2985 2023-03-05  OpenAI                 8.24               3.58
# 2986 2023-03-06  OpenAI                 9.32               4.21
# 2987 2023-03-07  OpenAI                 8.52               4.13
# 2988 2023-03-08  OpenAI                 8.90               3.63
# 2989 2023-03-09  OpenAI                 8.44               4.64
# 2990 2023-03-10  OpenAI                 9.55               4.83
# 2991 2023-03-11  OpenAI                 8.34               3.95
# 2992 2023-03-12  OpenAI                 8.71               3.57
# 2993 2023-03-13  OpenAI                10.61               5.19
# 2994 2023-03-14  OpenAI                 7.78               4.05
# 2995 2023-03-15  OpenAI                12.31               4.44
# 2996 2023-03-16  OpenAI                10.60               4.64
# 2997 2023-03-17  OpenAI                10.77               4.78
# ...

# %%
plt.figure(figsize = (10,4))

plt.plot( gpt4['Date'], gpt4['Stock_Impact_%'], color = 'green')

plt.title("Comparison before and after the release of GPT-4")
plt.xlabel("Date")
plt.ylabel("Change in Stock %")

plt.show()
